# %%
import weather
# Out:
# Weather report: -f
#
#      \  /       Partly cloudy
#    _ /"".-.     +24(26) °C
#      \_(   ).   ↘ 0 km/h
#      /(___(__)  10 km
#                 0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 25 Jan ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Partly cloudy  │    \  /       Partly cloudy  │  _`/"".-.     Patchy rain po…│  _`/"".-.     Light rain sho…│
# │  _ /"".-.     +25(28) °C     │  _ /"".-.     +30(36) °C     │   ,\_(   ).   +28(32) °C     │   ,\_(   ).   +25(28) °C     │
# ...

# %%
import sys
import requests

# %%
resp = requests.get(f'https://wttr.in/{sys.argv[1].replace(" ", "+")}')
print(resp.text)
# Out:
# Weather report: -f
#
#      \  /       Partly cloudy
#    _ /"".-.     +24(26) °C
#      \_(   ).   ↘ 0 km/h
#      /(___(__)  10 km
#                 0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Tue 25 Jan ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │    \  /       Partly cloudy  │    \  /       Partly cloudy  │  _`/"".-.     Patchy rain po…│  _`/"".-.     Light rain sho…│
# │  _ /"".-.     +25(28) °C     │  _ /"".-.     +30(36) °C     │   ,\_(   ).   +28(32) °C     │   ,\_(   ).   +25(28) °C     │
# ...

# %%
weather.py "San Antonio"
# Out:
#   File "/var/folders/9y/17ptyrds267724n2_7s7hx340000gn/T/ipykernel_22582/421868972.py", line 1
#     weather.py "San Antonio"
#                ^
# SyntaxError: invalid syntax
